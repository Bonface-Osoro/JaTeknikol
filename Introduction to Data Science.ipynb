# %% [markdown]
# ### Creating Dataframes using Pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('africa.csv')

# %%
df
# Out:
#         country independence colonizer  coups successful
# 0         Kenya     12/12/63   Britain      1          0
# 1       Nigeria       6/1/61   Britain      8          6
# 2      Ethiopia          NaN       NaN      5          5
# 3       Namibia   21/03/1990   Germany      0          _
# 4   South Sudan       9/7/11       NaN      1          0
# 5       Senegal       4/4/60    France      1          0
# 6          Chad      11/8/60    France      7          2
# 7        Angola     11/11/75  Portugal      1          0
# 8           DRC   30/06/1960   Belgium      4          2
# 9    Mozambique   25/06/1975  Portugal      1          1
# 10      Liberia   26/07/1847       NaN      4          1

# %%
df.head()
# Out:
#        country independence colonizer  coups successful
# 0        Kenya     12/12/63   Britain      1          0
# 1      Nigeria       6/1/61   Britain      8          6
# 2     Ethiopia          NaN       NaN      5          5
# 3      Namibia   21/03/1990   Germany      0          _
# 4  South Sudan       9/7/11       NaN      1          0

# %%
df.columns
# Out:
# Index(['country', 'independence', 'colonizer', 'coups', 'successful'], dtype='object')

# %%
df.shape
# Out:
# (11, 5)

# %%
rows, columns = df.shape

# %%
rows
# Out:
# 11

# %%
columns
# Out:
# 5

# %%
df.head(7)
# Out:
#        country independence colonizer  coups successful
# 0        Kenya     12/12/63   Britain      1          0
# 1      Nigeria       6/1/61   Britain      8          6
# 2     Ethiopia          NaN       NaN      5          5
# 3      Namibia   21/03/1990   Germany      0          _
# 4  South Sudan       9/7/11       NaN      1          0
# 5      Senegal       4/4/60    France      1          0
# 6         Chad      11/8/60    France      7          2

# %%
df.tail(3)
# Out:
#        country independence colonizer  coups successful
# 8          DRC   30/06/1960   Belgium      4          2
# 9   Mozambique   25/06/1975  Portugal      1          1
# 10     Liberia   26/07/1847       NaN      4          1

# %%
df[['country', 'colonizer', 'coups']]
# Out:
#         country colonizer  coups
# 0         Kenya   Britain      1
# 1       Nigeria   Britain      8
# 2      Ethiopia       NaN      5
# 3       Namibia   Germany      0
# 4   South Sudan       NaN      1
# 5       Senegal    France      1
# 6          Chad    France      7
# 7        Angola  Portugal      1
# 8           DRC   Belgium      4
# 9    Mozambique  Portugal      1
# 10      Liberia       NaN      4

# %%
df[3:6]
# Out:
#        country independence colonizer  coups successful
# 3      Namibia   21/03/1990   Germany      0          _
# 4  South Sudan       9/7/11       NaN      1          0
# 5      Senegal       4/4/60    France      1          0

# %%
df.country
# Out:
# 0           Kenya
# 1         Nigeria
# 2        Ethiopia
# 3         Namibia
# 4     South Sudan
# 5         Senegal
# 6            Chad
# 7          Angola
# 8             DRC
# 9      Mozambique
# 10        Liberia
# Name: country, dtype: object

# %%
df['country']
# Out:
# 0           Kenya
# 1         Nigeria
# 2        Ethiopia
# 3         Namibia
# 4     South Sudan
# 5         Senegal
# 6            Chad
# 7          Angola
# 8             DRC
# 9      Mozambique
# 10        Liberia
# Name: country, dtype: object

# %% [markdown]
# #### Basic Descriptive Statistics in Pandas

# %%
df.head()
# Out:
#        country independence colonizer  coups successful
# 0        Kenya     12/12/63   Britain      1          0
# 1      Nigeria       6/1/61   Britain      8          6
# 2     Ethiopia          NaN       NaN      5          5
# 3      Namibia   21/03/1990   Germany      0          _
# 4  South Sudan       9/7/11       NaN      1          0

# %%
df['coups'].max()
# Out:
# 8

# %%
df['coups'].min()
# Out:
# 0

# %%
df['coups'].mean()
# Out:
# 3.0

# %%
df['coups'].std()
# Out:
# 2.756809750418044

# %%
df.describe()
# Out:
#           coups
# count  11.00000
# mean    3.00000
# std     2.75681
# min     0.00000
# 25%     1.00000
# 50%     1.00000
# 75%     4.50000
# max     8.00000

# %%
df.head()
# Out:
#        country independence colonizer  coups successful
# 0        Kenya     12/12/63   Britain      1          0
# 1      Nigeria       6/1/61   Britain      8          6
# 2     Ethiopia          NaN       NaN      5          5
# 3      Namibia   21/03/1990   Germany      0          _
# 4  South Sudan       9/7/11       NaN      1          0

# %% [markdown]
# #### Conditionally select data

# %%
df[df.coups >= 5]
# Out:
#     country independence colonizer  coups successful
# 1   Nigeria       6/1/61   Britain      8          6
# 2  Ethiopia          NaN       NaN      5          5
# 6      Chad      11/8/60    France      7          2

# %%
df[df.coups >= 7]
# Out:
#    country independence colonizer  coups successful
# 1  Nigeria       6/1/61   Britain      8          6
# 6     Chad      11/8/60    France      7          2

# %%
df[df['coups'] == df['coups'].max()]
# Out:
#    country independence colonizer  coups successful
# 1  Nigeria       6/1/61   Britain      8          6

# %%
df[['country', 'colonizer']][df['coups'] == df['coups'].max()]
# Out:
#    country colonizer
# 1  Nigeria   Britain

# %% [markdown]
# ### Indexes

# %%
df.index
# Out:
# RangeIndex(start=0, stop=11, step=1)

# %%
df.set_index('independence')
# Out:
#                   country colonizer  coups successful
# independence
# 12/12/63            Kenya   Britain      1          0
# 6/1/61            Nigeria   Britain      8          6
# NaN              Ethiopia       NaN      5          5
# 21/03/1990        Namibia   Germany      0          _
# 9/7/11        South Sudan       NaN      1          0
# 4/4/60            Senegal    France      1          0
# 11/8/60              Chad    France      7          2
# 11/11/75           Angola  Portugal      1          0
# 30/06/1960            DRC   Belgium      4          2
# 25/06/1975     Mozambique  Portugal      1          1
# 26/07/1847        Liberia       NaN      4          1

# %%
df
# Out:
#         country independence colonizer  coups successful
# 0         Kenya     12/12/63   Britain      1          0
# 1       Nigeria       6/1/61   Britain      8          6
# 2      Ethiopia          NaN       NaN      5          5
# 3       Namibia   21/03/1990   Germany      0          _
# 4   South Sudan       9/7/11       NaN      1          0
# 5       Senegal       4/4/60    France      1          0
# 6          Chad      11/8/60    France      7          2
# 7        Angola     11/11/75  Portugal      1          0
# 8           DRC   30/06/1960   Belgium      4          2
# 9    Mozambique   25/06/1975  Portugal      1          1
# 10      Liberia   26/07/1847       NaN      4          1

# %%
df.set_index('independence', inplace = True)

# %%
df
# Out:
#                   country colonizer  coups successful
# independence
# 12/12/63            Kenya   Britain      1          0
# 6/1/61            Nigeria   Britain      8          6
# NaN              Ethiopia       NaN      5          5
# 21/03/1990        Namibia   Germany      0          _
# 9/7/11        South Sudan       NaN      1          0
# 4/4/60            Senegal    France      1          0
# 11/8/60              Chad    France      7          2
# 11/11/75           Angola  Portugal      1          0
# 30/06/1960            DRC   Belgium      4          2
# 25/06/1975     Mozambique  Portugal      1          1
# 26/07/1847        Liberia       NaN      4          1

# %%
df
# Out:
#                   country colonizer  coups successful
# independence
# 12/12/63            Kenya   Britain      1          0
# 6/1/61            Nigeria   Britain      8          6
# NaN              Ethiopia       NaN      5          5
# 21/03/1990        Namibia   Germany      0          _
# 9/7/11        South Sudan       NaN      1          0
# 4/4/60            Senegal    France      1          0
# 11/8/60              Chad    France      7          2
# 11/11/75           Angola  Portugal      1          0
# 30/06/1960            DRC   Belgium      4          2
# 25/06/1975     Mozambique  Portugal      1          1
# 26/07/1847        Liberia       NaN      4          1

# %%
df.loc['11/11/75']
# Out:
# country         Angola
# colonizer     Portugal
# coups                1
# successful           0
# Name: 11/11/75, dtype: object

# %%
df
# Out:
#                   country colonizer  coups successful
# independence
# 12/12/63            Kenya   Britain      1          0
# 6/1/61            Nigeria   Britain      8          6
# NaN              Ethiopia       NaN      5          5
# 21/03/1990        Namibia   Germany      0          _
# 9/7/11        South Sudan       NaN      1          0
# 4/4/60            Senegal    France      1          0
# 11/8/60              Chad    France      7          2
# 11/11/75           Angola  Portugal      1          0
# 30/06/1960            DRC   Belgium      4          2
# 25/06/1975     Mozambique  Portugal      1          1
# 26/07/1847        Liberia       NaN      4          1

# %%
df.reset_index(inplace = True)

# %%
df
# Out:
#    independence      country colonizer  coups successful
# 0      12/12/63        Kenya   Britain      1          0
# 1        6/1/61      Nigeria   Britain      8          6
# 2           NaN     Ethiopia       NaN      5          5
# 3    21/03/1990      Namibia   Germany      0          _
# 4        9/7/11  South Sudan       NaN      1          0
# 5        4/4/60      Senegal    France      1          0
# 6       11/8/60         Chad    France      7          2
# 7      11/11/75       Angola  Portugal      1          0
# 8    30/06/1960          DRC   Belgium      4          2
# 9    25/06/1975   Mozambique  Portugal      1          1
# 10   26/07/1847      Liberia       NaN      4          1

# %%
df.set_index('colonizer', inplace = True)

# %%
df
# Out:
#           independence      country  coups successful
# colonizer
# Britain       12/12/63        Kenya      1          0
# Britain         6/1/61      Nigeria      8          6
# NaN                NaN     Ethiopia      5          5
# Germany     21/03/1990      Namibia      0          _
# NaN             9/7/11  South Sudan      1          0
# France          4/4/60      Senegal      1          0
# France         11/8/60         Chad      7          2
# Portugal      11/11/75       Angola      1          0
# Belgium     30/06/1960          DRC      4          2
# Portugal    25/06/1975   Mozambique      1          1
# NaN         26/07/1847      Liberia      4          1

# %%
df.loc['Britain']
# Out:
#           independence  country  coups successful
# colonizer
# Britain       12/12/63    Kenya      1          0
# Britain         6/1/61  Nigeria      8          6

# %%
df.loc['France']
# Out:
#           independence  country  coups successful
# colonizer
# France          4/4/60  Senegal      1          0
# France         11/8/60     Chad      7          2

# %%
df.loc['Portugal']
# Out:
#           independence     country  coups successful
# colonizer
# Portugal      11/11/75      Angola      1          0
# Portugal    25/06/1975  Mozambique      1          1

# %%
df = pd.read_excel('africa.xlsx', 'Sheet1')

# %%
df.head()
# Out:
#        country         independence colonizer  coups successful
# 0        Kenya  1963-12-12 00:00:00   Britain      1          0
# 1      Nigeria  1961-06-01 00:00:00   Britain      8          6
# 2     Ethiopia                  NaN       NaN      5          5
# 3      Namibia           21/03/1990   Germany      0          _
# 4  South Sudan  2011-09-07 00:00:00       NaN      1          0

# %%
df = pd.read_excel('africa.xlsx', 'Sheet1', nrows = 3)

# %%
df = pd.read_excel('africa.xlsx', 'Sheet1', na_values = ['NA', '_'])

# %%
df
# Out:
#         country         independence colonizer  coups  successful
# 0         Kenya  1963-12-12 00:00:00   Britain      1         0.0
# 1       Nigeria  1961-06-01 00:00:00   Britain      8         6.0
# 2      Ethiopia                  NaN       NaN      5         5.0
# 3       Namibia           21/03/1990   Germany      0         NaN
# 4   South Sudan  2011-09-07 00:00:00       NaN      1         0.0
# 5       Senegal  1960-04-04 00:00:00    France      1         0.0
# 6          Chad  1960-11-08 00:00:00    France      7         2.0
# 7        Angola  1975-11-11 00:00:00  Portugal      1         0.0
# 8           DRC           30/06/1960   Belgium      4         2.0
# 9    Mozambique           25/06/1975  Portugal      1         1.0
# 10      Liberia           26/07/1847       NaN      4         1.0

# %%
df.to_csv('new_africa.csv', index = False)

# %% [markdown]
# #### Handling Time data

# %%
df = pd.read_csv('africa.csv', parse_dates = ['independence'], na_values = ['NA', '_'])
# Out:
# /Users/osoro/anaconda3/envs/OpenStreetMap/lib/python3.9/site-packages/pandas/io/parsers/base_parser.py:1070: UserWarning: Parsing '21/03/1990' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# /Users/osoro/anaconda3/envs/OpenStreetMap/lib/python3.9/site-packages/pandas/io/parsers/base_parser.py:1070: UserWarning: Parsing '30/06/1960' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# /Users/osoro/anaconda3/envs/OpenStreetMap/lib/python3.9/site-packages/pandas/io/parsers/base_parser.py:1070: UserWarning: Parsing '25/06/1975' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# /Users/osoro/anaconda3/envs/OpenStreetMap/lib/python3.9/site-packages/pandas/io/parsers/base_parser.py:1070: UserWarning: Parsing '26/07/1847' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(

# %%
df
# Out:
#         country independence colonizer  coups  successful
# 0         Kenya   2063-12-12   Britain      1         0.0
# 1       Nigeria   2061-06-01   Britain      8         6.0
# 2      Ethiopia          NaT       NaN      5         5.0
# 3       Namibia   1990-03-21   Germany      0         NaN
# 4   South Sudan   2011-09-07       NaN      1         0.0
# 5       Senegal   2060-04-04    France      1         0.0
# 6          Chad   2060-11-08    France      7         2.0
# 7        Angola   1975-11-11  Portugal      1         0.0
# 8           DRC   1960-06-30   Belgium      4         2.0
# 9    Mozambique   1975-06-25  Portugal      1         1.0
# 10      Liberia   1847-07-26       NaN      4         1.0

# %%
type(df.independence[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df.isna()
# Out:
#     country  independence  colonizer  coups  successful
# 0     False         False      False  False       False
# 1     False         False      False  False       False
# 2     False          True       True  False       False
# 3     False         False      False  False        True
# 4     False         False       True  False       False
# 5     False         False      False  False       False
# 6     False         False      False  False       False
# 7     False         False      False  False       False
# 8     False         False      False  False       False
# 9     False         False      False  False       False
# 10    False         False       True  False       False

# %%
df.dropna()
# Out:
#       country independence colonizer  coups  successful
# 0       Kenya   2063-12-12   Britain      1         0.0
# 1     Nigeria   2061-06-01   Britain      8         6.0
# 5     Senegal   2060-04-04    France      1         0.0
# 6        Chad   2060-11-08    France      7         2.0
# 7      Angola   1975-11-11  Portugal      1         0.0
# 8         DRC   1960-06-30   Belgium      4         2.0
# 9  Mozambique   1975-06-25  Portugal      1         1.0

# %%
df['colonizer'].nunique()
# Out:
# 5

# %%
df.sort_values(by = ['coups'], ascending = True)
# Out:
#         country independence colonizer  coups  successful
# 3       Namibia   1990-03-21   Germany      0         NaN
# 0         Kenya   2063-12-12   Britain      1         0.0
# 4   South Sudan   2011-09-07       NaN      1         0.0
# 5       Senegal   2060-04-04    France      1         0.0
# 7        Angola   1975-11-11  Portugal      1         0.0
# 9    Mozambique   1975-06-25  Portugal      1         1.0
# 8           DRC   1960-06-30   Belgium      4         2.0
# 10      Liberia   1847-07-26       NaN      4         1.0
# 2      Ethiopia          NaT       NaN      5         5.0
# 6          Chad   2060-11-08    France      7         2.0
# 1       Nigeria   2061-06-01   Britain      8         6.0

# %%
df
# Out:
#         country independence colonizer  coups  successful
# 0         Kenya   2063-12-12   Britain      1         0.0
# 1       Nigeria   2061-06-01   Britain      8         6.0
# 2      Ethiopia          NaT       NaN      5         5.0
# 3       Namibia   1990-03-21   Germany      0         NaN
# 4   South Sudan   2011-09-07       NaN      1         0.0
# 5       Senegal   2060-04-04    France      1         0.0
# 6          Chad   2060-11-08    France      7         2.0
# 7        Angola   1975-11-11  Portugal      1         0.0
# 8           DRC   1960-06-30   Belgium      4         2.0
# 9    Mozambique   1975-06-25  Portugal      1         1.0
# 10      Liberia   1847-07-26       NaN      4         1.0

# %%
df.transpose()
# Out:
#                                0                    1         2   \
# country                     Kenya              Nigeria  Ethiopia
# independence  2063-12-12 00:00:00  2061-06-01 00:00:00       NaT
# colonizer                 Britain              Britain       NaN
# coups                           1                    8         5
# successful                    0.0                  6.0       5.0
#
#                                3                    4                    5   \
# country                   Namibia          South Sudan              Senegal
# independence  1990-03-21 00:00:00  2011-09-07 00:00:00  2060-04-04 00:00:00
# colonizer                 Germany                  NaN               France
# coups                           0                    1                    1
# successful                    NaN                  0.0                  0.0
#
#                                6                    7                    8   \
# country                      Chad               Angola                  DRC
# independence  2060-11-08 00:00:00  1975-11-11 00:00:00  1960-06-30 00:00:00
# colonizer                  France             Portugal              Belgium
# coups                           7                    1                    4
# successful                    2.0                  0.0                  2.0
#
#                                9                    10
# country                Mozambique              Liberia
# independence  1975-06-25 00:00:00  1847-07-26 00:00:00
# colonizer                Portugal                  NaN
# coups                           1                    4
# successful                    1.0                  1.0
